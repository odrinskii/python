# %% [markdown]
# # PIP

# %%
import matplotlib.pyplot as plt

# %%
lis = [10, 5, 12, 3, 2]

# %%
plt.plot(lis, "ro")

# %%
from sympy import *
from sympy.plotting import plot
init_printing()

# %%
x = Symbol('x')

# %%
f = x + 2022
f
# Out:
# x + 2022

# %%
plot(f)
f
# Out:
# x + 2022
